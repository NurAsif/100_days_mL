# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as n

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}
url ='https://www.glassdoor.com/Reviews/index.htm?filterType=RATING_OVERALL&page=1&overall_rating_low=4'
response = requests.get(url, headers=headers).text

# %%
soup = BeautifulSoup(response, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Security | Glassdoor
#   </title>
#   <meta content="text/html;charset=utf-8" http-equiv="content-type"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="#0caa41" name="theme-color"/>
#   <style type="text/css">
#    body,html{background:#fff;font-family:Helvetica Neue,HelveticaNeue,Helvetica,Arial,sans-serif;font-size:16px;margin:0;padding:0}div,h1,h2,h3,h4,h5,h6,p{color:#20262e}.header{-webkit-box-shadow:inset 0 -1px 0 0 #dee0e3;box-shadow:inset 0 -1px 0 0 #dee0e3}.header .center{height:45px}.header .center:before{content:"";height:100%;margin-right:-.25em}.header .center:before,.logo{display:inline-block;vertical-align:middle}.center{margin:0 auto;width:996px}.article,.center{box-sizing:border-box}.article{background-color:#fff;border-radius:3px;box-shadow:0 0 2px #c4c7cc;height:100%;margin:16px 0;max-width:690px;padding:16px}h1{font-size:20px;font-weight:900;line-height:1em;margin-top:0}h2{font-size:18px;font-weight:400;margin:16px 0}@media only screen and (max-width:767px){.header .center{text-align:center}.center{padding:0;width:100%}.article{margin:16px;max-width:none}}@media only screen and (min-width:768px) and (max-width:1023px){.center{margin:0;padding:0 14px;width:100%}}
#   </style>
#   <meta content="360" http-equiv="refresh"/>
#  </head>
#  <body>
#   <div class="header">
#    <div class="center">
#     <img class="logo" height="30" src="data:image/png;base64,..." width="144"/>
#    </div>
#   </div>
#   <div class="center">
#    <div class="article lang en-us">
#     <h1>
#      Help Us Protect Glassdoor
#     </h1>
#     <p>
#      Please help us protect Glassdoor by verifying that you're a
# 		real person. We are sorry for the inconvenience. If you continue to see this
# 		message, please email
#      <img src="data:image/jpeg;base64,..." style="margin-bottom:-4px"/>
#      to let us know you're having trouble.
#     </p>
#    </div>
#    <div class="article lang fr-fr">
#     <h1>
#      Aidez-nous à protéger Glassdoor
#     </h1>
#     <p>
#      Aidez-nous à protéger Glassdoor en confirmant que vous êtes une personne réelle.
# 		Nous sommes désolés pour la gêne occasionnée. Si vous continuez à voir ce
# 		message, contactez-nous à l'adresse
#      <img src="data:image/jpeg;base64,..." style="margin-bottom:-4px"/>
#      pour nous faire part du problème.
#     </p>
#    </div>
#    <div class="article lang de-de">
#     <h1>
#      Helfen Sie mit, Glassdoor zu schützen
#     </h1>
#     <p>
#      Bitte helfen Sie uns, Glassdoor zu schützen, indem Sie bestätigen, dass Sie
# 		ein Mensch und keine Maschine sind. Wir entschuldigen uns für die Umstände. Wenn
# 		Sie weiterhin diese Meldung erhalten, informieren Sie uns darüber bitte per E-Mail
# 		an
#      <img src="data:image/jpeg;base64,..." style="margin-bottom:-4px"/>
#     </p>
#    </div>
#    <div class="article lang nl-nl">
#     <h1>
#      Help ons Glassdoor te beschermen
#     </h1>
#     <p>
#      Help ons Glassdoor te beschermen door te verifiëren of u een persoon bent. Onze
# 		excuses voor het ongemak. Als u dit bericht blijft zien, stuur dan een e-mail
# 		naar
#      <img src="data:image/jpeg;base64,..." style="margin-bottom:-4px"/>
#      om ons te informeren over dit probleem.
#     </p>
#    </div>
#    <div class="article lang es-es">
#     <h1>
#      Ayúdanos a proteger Glassdoor
#     </h1>
#     <p>
#      Ayúdanos a proteger Glassdoor y demuéstranos que eres una persona real. Disculpa
# 		las molestias. Si continúas recibiendo este mensaje, infórmanos del problema
# 		enviando un correo electrónico a
#      <img src="data:image/jpeg;base64,..." style="margin-bottom:-4px"/>
#      .
#     </p>
#    </div>
#    <div class="article lang es-419">
#     <h1>
#      Ayúdanos a proteger Glassdoor
#     </h1>
#     <p>
#      Ayúdanos a proteger Glassdoor verificando que eres una persona real. Lamentamos
# 		los inconvenientes que esto te pueda causar. Si continúas viendo este mensaje,
# 		envía un correo electrónico a
#      <img src="data:image/jpeg;base64,..." style="margin-bottom:-4px"/>
#      para informarnos de que tienes problemas.
#     </p>
#    </div>
#    <div class="article lang pt-br">
#     <h1>
#      Ajude-nos a proteger o Glassdoor
#     </h1>
#     <p>
#      Ajude-nos a manter o Glassdoor seguro confirmando que você é uma pessoa de
# 		verdade. Lamentamos pelo inconveniente. Caso continue recebendo esta mensagem,
# 		envie um e-mail para
#      <img src="data:image/jpeg;base64,..." style="margin-bottom:-4px"/>
#      para nos informar sobre o problema.
#     </p>
#    </div>
#    <div class="article lang it-it">
#     <h1>
#      Aiutaci a proteggere Glassdoor
#     </h1>
#     <p>
#      Aiutaci a proteggere Glassdoor dimostrando che sei una persona reale. Ci
# 		scusiamo se questo può causarti degli inconvenienti. Se continui a visualizzare
# 		questo messaggio, invia un'email all'indirizzo
#      <img src="data:image/jpeg;base64,..." style="margin-bottom:-4px"/>
#      per informarci del problema.
#     </p>
#    </div>
#    <div class="article">
#     <p>
#      CF-103 / 95c505580d52dae2
#     </p>
#     <p>
#      <div class="main-wrapper" role="main">
#       <div class="main-content">
#        <noscript>
#         <div class="h2">
#          <span id="challenge-error-text">
#           Enable JavaScript and cookies to continue
#          </span>
#         </div>
#        </noscript>
#       </div>
#      </div>
#      <script>
#       (function(){window._cf_chl_opt={cvId: '3',cZone: "www.glassdoor.com",cType: 'managed',cRay: '95c505580d52dae2',cH: 'dt2gf49NjFJpZniH5RUcf34XHR3Dtvnhwz_o6A36z6c-1752034743-1.2.1.1-j__2VosDx205cdO1waWcuJDxwymIUG82eQUiXEf94oQ6mZsFNp3hfGDywUvKeQQi',cUPMDTk: "\/Reviews\/index.htm?filterType=RATING_OVERALL&page=1&overall_rating_low=4&__cf_chl_tk=5_T3MxgjyeIbQchGEy1XsMmco76KgzBFz7HzgHJwRvM-1752034743-1.0.1.1-1AQbz.NLq9iOpqfBz3BO99PlVI3Wu3s58EontLehAT4",cFPWv: 'b',cITimeS: '1752034743',cTplC: 1,cTplV: 5,cTplB: 'cf',fa: "\/Reviews\/index.htm?filterType=RATING_OVERALL&page=1&overall_rating_low=4&__cf_chl_f_tk=5_T3MxgjyeIbQchGEy1XsMmco76KgzBFz7HzgHJwRvM-1752034743-1.0.1.1-1AQbz.NLq9iOpqfBz3BO99PlVI3Wu3s58EontLehAT4",md: "E0EaO3ig9YybpRGAigJEFEATNS.WkxyhljWvLEolzC8-1752034743-1.2.1.1-BWnydjsd7WCk3UYlulEJSGbAlcFtr.SgWwAUlomQocGG8WYH2XFUMCU2_bXzNjLoRtIfzk02HgxpJ14xwK44uDRGNdk144emNlZP18dF49OlT2wsNLzbaKWouC1oGhpB7XcuqdIM.ycAOjEOInjwFK7yyBwkD7zqO1IYHFe_agNEvtNqYw.UqkJnWC7e2JEXCfRMI3gfQUUSDfZ.h98K0qZGZUqsd5Mu0NusIi5IL74DGQ1FNaM5yVfLrDHqkaY5MWJkF854WGlS5mEYIwdALurpp_mSk_1fmPfF6uakqR0PI5ZRXxUgbWrg_QTGrfHEh9s0r0FqUvRukreZ5F.PatzXH0Gs5IXwguV7trCyPS57fBx.RsRaH6Nvc5rawf5ofkLv2vyBnzun4edbyCYauAQut_Vzp1K0W01slS2a_nVrosEU8BBD75J9v9QrKo8AJWfXl1Hsw0Pf9QEjR7X5UlsRWY.meBe3nH9dWX3DASaTVSG7h4wxQyULCUIPh8SPtK8FB_UxfhhCNMMFKrcItbJeFDziskpX4iMe28UYuVreKfFDNTKlFEbb9UAG6rpPHtVj7BNyUY_1Q64zrFLfFbhzev4AaHpJoEtdij.UKRNBhWb4_RB7BnDIM6ZDO6_IstQxI29TkcAUhOSAG0amZ_2.Fln0OEVyYsGJ_tezzDSzJyQD5MgmFD6u2Ujakuivq5L0wYL_DUfvTW8wUo9gREcEGl9NU3gqEVclwM2A2G9ay2rkz.sShbn1skYXsYqa3MHlQ4Y39I9P1NBRENlbqVF6Q7_KGIpl0pH93.heh3CgzS_AqRFrS7AD7tStG4YfmHchW9gu_AuQw10I8Cy9Dkx5eo2UwDa2tmPXySEdt0sVMp3N2ASJPHs93_z.MeT1ULAxqvB25N2cAaxQTfAtUEK8dQ2mi6DoYLzEjR5DwLCONsLqwr4RNmlye_KOXDGGma8Bjoh1rP4aLxhMPTUgizNWqc2AnNSaPLjU89WrjZ1ZtXqlxAapjh.gluu6RKtqQF84A94.zHk2O1Unaonna4xMcOfHnVTVkHHChK3NqMIl9jAtJMFX.abKWEhAcgFBMruFO1UreUnqDX1W5gWhRnEzHYCl6IGsqnqQM2bve1324ukucIJJqg9n7kMmVmgjBEjQKdfU4w4QDBF0kbO5tWRrH7waNtr1AQmcWNk.GOk",mdrd: "Q8FVnmf5HZKXmxuGpUSSqzDZY3jjAib5yGg4W12p5YI-1752034743-1.2.1.1-tTZbgrmh75P.cZSfNnKnNGneO_25TZmnm.sjIhg1MoJ6_t7HHhqyCNvyVRVz_34cN26Ut1gv5.Qb0NVSGVh9RO2dftOrN6q7FvMyty5kRZuQpnlWNRnm7MRv0AWGFbUtxYY.7XIUB1YLzgLMQMAoK.Hlhf_Ss8P0GWmz7P1RkW7tjGufSInjNXnBqn6ZsMD7ZmLFwH2.2ZwZg9drdXHnqEwbkIIkLoRQH5gLOBGGk0d.vPgYvxwviirpBh2I1SehVANr6vxA42z72je.gtpgoi1HxdIRn3Ax9VlS.lFUZ7IfHoZvab94go7UQfYKALcl5c6shRwGy7SfHXxSmU0RL4p1iAwDcRjRBLHS3Gxkj.CsqbVhD3ri0JCSjKaxqKtEygSaaXnHjRydIVn.BSi7.MUUh28UIWMG1NgBb3YPVy0p3kmvQiRk51yUuIhnXJ7EL.pJvus68URnP2fY8It2pCwjboY5wFaQ7mv7fpSEI5rsVg4lT7kQOfhr.VLJxkg9XL68Hd8Xmi4PsAtCzCUvtq8Vs5.OE4GkicU48qelSGpihkaNNEJqdvSWHTO2_Ddl0pRtuvXg9yK1F3NhCPBs0ufCXkDkPqTz8tx0eBmyyiuqSgBtpnzpDb8YFZ28zSEhT_cWY8AwQHgTYiSP7MA0RMAIqDNEfLvt8vEfMcisdQqJkMIrpfK_xmW5oywAjF3OG9Jxmi5CwPzhE2cbwBbBv.fBxCASlMI2kvlXlcmKREZYExBoOHayasyMaq1rEqFc2br7eNWu0koNpQbPex8BRK8_Ze1FYJe5wpyr4z0UUCRYYxQiHydtkYXlr3XMXXhY4sWZ992.sl0dNVq4p1d9niLwIT2TZP_6s0m4YZUrqyW6uukGmgk6U7j6GKGE4yXZ5Cr4kNrvhtovLMMGO.Lriau4hiCr1CcSznk.wuVawtIoh9tHqj.js0yR.1woo1sT9HzvqmjldpP.eFGDb8s04Qjn3KLW6mnRUhM4HicObR709_By2zMwWbCqvEWRXESorWU0tkh1Ii7w.AWsZXftkDp_I2oggLsZVGxsHKT98W60lQ5j5ZpS7SehbiHT2bk7WeSmOtnwzEtRzje2USnDqPQkM3k1oUyze40Ihs2XxHU_2PqvXzI2dYT1tirPHENmcul_cZVwlvYfr5m.vNq4SkPKVqYEGe3HbfAJ5T5ayonUtX6.CPw.gO.fZSEVglm0ja7aLZTG7XXeJwL7aGlgFy98OlhEqeNTDM0SuGW5KIlF70wmQU_IHPMSXyxgMPIlFNkeMEFMtf1VKYJQbMY0qCnchRoFQ51ig2b9JgiYs59xvzzxMlcVLdd2vAtNEA8oxLjM5TD86plcxvAQycpdDawLE7rMP5p2HK2kz0TBD_PTUOR89van9XAQ7b.tTcfivGNmqdxX0SDucue_N1ckgt_.vaY6VCL44hqxVUv7rdRkoC7eHS2xDy9IBWG9KON2oLNsowCpke8E2ZEKd5f7IoTKquQtE4gP1y6.BLOKwVjNT5MRLfvlDvdXToZ4sYvbKvSANDAHUFf_.h85MPB.IdsO5MI8vlIZxvCllfO0UGmT3VkZ2jJQS90wACvFMf2KGHEkSUaCeJ1TMHSDIsZDnSVCdHg_Tsb8ripbVepLEe4fUPr8OFaluZI3ayMHQLAVm.EvGXxIgK0LQ3MKlTvHhnfDCRsDNnhsmip0PiiGYh.qANv9qSlYnflFJFF2sVsSPbpDNRi9UEJkRDLpv1lSuTXuQqdoVT.KTSqVpEzRzmrS2d08RwOXOBjyQb0JzvEZupO5g3njJnhoHoLyPBIzkan4paqrYrLdReGyzKJUUG6hE1tJTo1wFV9B7PkR59nRkd_phOEel7pV8LNQB1EebAf7osOSwrt70.qHW_OiGnV2FX_WJgHwbIaaOeekNrjxOdzGTzrdsKlZiqzs4Vo.Nn0X ...
#      </script>
#     </p>
#    </div>
#   </div>
#   <script>
#    !function(){for(var s,o,d=(s=window.location.hostname,(o=s).endsWith("glassdoor.fr")?"fr-fr":o.endsWith("glassdoor.de")?"de-de":o.endsWith("glassdoor.nl")||o.endsWith("nl.glassdoor.be")?"nl-nl":o.endsWith("fr.glassdoor.be")||o.endsWith("fr.glassdoor.ch")?"fr-fr":o.endsWith("de.glassdoor.ch")||o.endsWith("glassdoor.at")?"de-de":o.endsWith("fr.glassdoor.ca")?"fr-fr":o.endsWith("glassdoor.es")?"es-es":o.endsWith("glassdoor.com.ar")||o.endsWith("glassdoor.com.mx")?"es-419":o.endsWith("glassdoor.com.br")?"pt-br":o.endsWith("glassdoor.it")?"it-it":"en-us"),e=document.getElementsByClassName("lang"),n=0,r=e.length;n<r;n++)-1==e[n].className.indexOf(d)&&(e[n].style.display="none")}();
#   </script>
#   <script>
#    !function(e,a,t,n,g,c,o){e.GoogleAnalyticsObject=g,e.ga=e.ga||function(){(e.ga.q=e.ga.q||[]).push(arguments)},e.ga.l=1*new Date,c=a.createElement(t),o=a.getElementsByTagName(t)[0],c.async=1,c.src="//www.google-analytics.com/analytics.js",o.parentNode.insertBefore(c,o)}(window,document,"script",0,"ga"),ga("create","UA-2595786-6","auto"),ga("send","pageview");
#   </script>
#  </body>
# </html>

# %%
soup.find_all('h1')[0].text
# Out:
# 'Help Us Protect Glassdoor'
